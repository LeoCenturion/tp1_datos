# %%
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd

# %%
trips = pd.read_csv('trip.csv')

# %%
trips.loc[22,'start_date']
# Out:
# Timestamp('2013-08-29 11:40:00')

# %%
datetime=datetime.strptime('2013-08-29 11:40:00', '%Y-%m-%d %H:%M:%S')
datetime.date()
# Out:
# datetime.date(2013, 8, 29)

# %%
trips.groupby('start_day').count()
# Out:
#               id  duration  start_date  start_station_name  start_station_id  \
# start_day
# 2013-08-29   748       748         748                 748               748
# 2013-08-30   714       714         714                 714               714
# 2013-08-31   640       640         640                 640               640
# 2013-09-01   706       706         706                 706               706
# 2013-09-02   661       661         661                 661               661
# 2013-09-03   597       597         597                 597               597
# 2013-09-04   606       606         606                 606               606
# 2013-09-05   677       677         677                 677               677
# 2013-09-06   814       814         814                 814               814
# 2013-09-07   796       796         796                 796               796
# 2013-09-08   704       704         704                 704               704
# 2013-09-09   769       769         769                 769               769
# 2013-09-10   892       892         892                 892               892
# 2013-09-11   880       880         880                 880               880
# 2013-09-12   942       942         942                 942               942
# 2013-09-13   981       981         981                 981               981
# 2013-09-14   702       702         702                 702               702
# 2013-09-15   624       624         624                 624               624
# 2013-09-16   914       914         914                 914               914
# 2013-09-17  1073      1073        1073                1073              1073
# 2013-09-18  1110      1110        1110                1110              1110
# 2013-09-19  1044      1044        1044                1044              1044
# 2013-09-20  1102      1102        1102                1102              1102
# 2013-09-21   388       388         388                 388               388
# 2013-09-22   584       584         584                 584               584
# 2013-09-23  1050      1050        1050                1050              1050
# 2013-09-24  1075      1075        1075                1075              1075
# 2013-09-25  1264      1264        1264                1264              1264
# 2013-09-26  1082      1082        1082                1082              1082
# 2013-09-27  1101      1101        1101                1101              1101
# ...          ...       ...         ...                 ...               ...
# 2015-08-02   320       320         320                 320               320
# 2015-08-03  1283      1283        1283                1283              1283
# 2015-08-04  1360      1360        1360                1360              1360
# 2015-08-05  1341      1341        1341                1341              1341
# 2015-08-06  1299      1299        1299                1299              1299
# 2015-08-07  1197      1197        1197                1197              1197
# 2015-08-08   432       432         432                 432               432
# 2015-08-09   361       361         361                 361               361
# 2015-08-10  1284      1284        1284                1284              1284
# 2015-08-11  1397      1397        1397                1397              1397
# 2015-08-12  1400      1400        1400                1400              1400
# 2015-08-13  1401      1401        1401                1401              1401
# 2015-08-14  1182      1182        1182                1182              1182
# 2015-08-15   451       451         451                 451               451
# 2015-08-16   393       393         393                 393               393
# 2015-08-17  1418      1418        1418                1418              1418
# 2015-08-18  1407      1407        1407                1407              1407
# 2015-08-22       421               421             421      421
# 2015-08-23       311               311             311      311
# 2015-08-24      1309              1309            1309     1309
# 2015-08-25      1421              1421            1421     1421
# 2015-08-26      1465              1465            1465     1465
# 2015-08-27      1443              1443            1443     1443
# 2015-08-28      1220              1220            1220     1220
# 2015-08-29       342               342             342      342
# 2015-08-30       331               331             331      331
# 2015-08-31      1369              1369            1369     1369
#
#             subscription_type  zip_code
# start_day
# 2013-08-29                748       706
# 2013-08-30                714       643
# 2013-08-31                640       567
# 2013-09-01                706       631
# 2013-09-02                661       578
# 2013-09-03                597       540
# 2013-09-04                606       558
# 2013-09-05                677       635
# 2013-09-06                814       735
# 2013-09-07                796       679
# 2013-09-08                704       607
# 2013-09-09                769       723
# 2013-09-10                892       820
# 2013-09-11                880       831
# 2013-09-12                942       886
# 2013-09-13                981       914
# 2013-09-14                702       618
# 2013-09-15                624       544
# 2013-09-16                914       834
# 2013-09-17               1073       977
# 2013-09-18               1110      1052
# 2013-09-19               1044       985
# 2013-09-20               1102      1037
# 2013-09-21                388       350
# 2013-09-22                584       519
# 2013-09-23               1050       999
# 2013-09-24               1075      1033
# 2013-09-25               1264      1207
# 2013-09-26               1082      1037
# 2013-09-27               1101      1059
# ...                       ...       ...
# 2015-08-02                320       315
# 2015-08-03               1283      1283
# 2015-08-04               1360      1360
# 2015-08-05               1341      1341
# 2015-08-06               1299      1299
# 2015-08-07               1197      1197
# 2015-08-08                432       429
# 2015-08-09                361       357
# 2015-08-10               1284      1284
# 2015-08-11               1397      1397
# 2015-08-12               1400      1399
# 2015-08-13               1401      1401
# 2015-08-14               1182      1181
# 2015-08-15                451       451
# 2015-08-16                393       393
# 2015-08-17               1418      1418
# 2015-08-18               1407      1407
# 2015-08-19               1353      1353
# 2015-08-20               1353      1353
# 2015-08-21               1215      1214
# 2015-08-22                421       417
# 2015-08-23                311       311
# 2015-08-24               1309      1309
# 2015-08-25               1421      1421
# 2015-08-26               1465      1465
# 2015-08-27               1443      1443
# 2015-08-28               1220      1220
# 2015-08-29                342       339
# 2015-08-30                331       331
# 2015-08-31               1369      1368
#
# [733 rows x 11 columns]

# %%
trips['start_date']=trips.start_date.map(lambda x: datetime.strptime(x, '%m/%d/%Y %H:%M') )

# %%
trips['start_day']=trips.start_date.map(lambda x: x.date() )

# %%
import plotly.plotly as py
import plotly.graph_objs as go 

from datetime import datetime
#import pandas_datareader.data as web

df = trips.groupby('start_day').count()

trace = go.Scatter(x=df.index,
                       y=df.id)

data = [trace]
layout = dict(
    title='Time series with range slider and selectors',
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1m',
                     step='month',
                     stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(count=1,
                    label='YTD',
                    step='year',
                    stepmode='todate'),
                dict(count=1,
                    label='1y',
                    step='year',
                    stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(),
        type='date'
    )
)

fig = dict(data=data, layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~leocenturion/31.embed" height="525px" width="100%"></iframe>
